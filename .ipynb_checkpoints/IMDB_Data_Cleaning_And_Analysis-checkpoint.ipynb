# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#tell pandas to display wide tables as pretty HTML tables
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %%
# !head imdb_top_10000.txt
# Out:
# tt0111161	The Shawshank Redemption (1994)	1994	 9.2	619479	142 mins.	Crime|Drama
# tt0110912	Pulp Fiction (1994)	1994	 9.0	490065	154 mins.	Crime|Thriller
# tt0137523	Fight Club (1999)	1999	 8.8	458173	139 mins.	Drama|Mystery|Thriller
# tt0133093	The Matrix (1999)	1999	 8.7	448114	136 mins.	Action|Adventure|Sci-Fi
# tt1375666	Inception (2010)	2010	 8.9	385149	148 mins.	Action|Adventure|Sci-Fi|Thriller
# tt0109830	Forrest Gump (1994)	1994	 8.7	368994	142 mins.	Comedy|Drama|Romance
# tt0169547	American Beauty (1999)	1999	 8.6	338332	122 mins.	Drama
# tt0499549	Avatar (2009)	2009	 8.1	336855	162 mins.	Action|Adventure|Fantasy|Sci-Fi
# tt0108052	Schindler's List (1993)	1993	 8.9	325888	195 mins.	Biography|Drama|History|War
# tt0080684	Star Wars: Episode V - The Empire Strikes Back (1980)	1980	 8.8	320105	124 mins.	Action|Adventure|Family|Sci-Fi

# %% [markdown]
# #1.Build a DataFrame from a txt file
#
# This Dataset consist from IMDB website of 10000 movies from 1950-2012 from this [link](http://www.imdb.com/search/title?sort=num_votes,desc&title_type=feature&year=1950,2012)

# %%
#Create a DataFrame by reading this file from a csv reader
names = ['imdbID', 'title', 'year', 'score', 'votes', 'runtime', 'genres']
data =pd.read_csv('imdb_top_10000.txt', sep='\t',names=names).dropna() # use dropna() function to remove 'NAN' rows(if any)
data.head()
# Out:
#       imdbID                            title  year  score   votes    runtime                            genres
# 0  tt0111161  The Shawshank Redemption (1994)  1994    9.2  619479  142 mins.                       Crime|Drama
# 1  tt0110912              Pulp Fiction (1994)  1994    9.0  490065  154 mins.                    Crime|Thriller
# 2  tt0137523                Fight Club (1999)  1999    8.8  458173  139 mins.            Drama|Mystery|Thriller
# 3  tt0133093                The Matrix (1999)  1999    8.7  448114  136 mins.           Action|Adventure|Sci-Fi
# 4  tt1375666                 Inception (2010)  2010    8.9  385149  148 mins.  Action|Adventure|Sci-Fi|Thriller

# %% [markdown]
# #2. Clean the DataFrame
#
# For each column check if the content of that column is good enough to proceed such as datatype for example: runtime column has
# number as well as string('mins'), we can remove 'mins' from that column.

# %%
#From title column removing the years and from runtime remove'mins'

data['title'] = [each[0:-7] for each in data['title']]
data['runtime'] = [int(each[0:-5]) for each in data['runtime']]

# %%
data.head()
# Out:
#       imdbID                     title  year  score   votes  runtime                            genres
# 0  tt0111161  The Shawshank Redemption  1994    9.2  619479      142                       Crime|Drama
# 1  tt0110912              Pulp Fiction  1994    9.0  490065      154                    Crime|Thriller
# 2  tt0137523                Fight Club  1999    8.8  458173      139            Drama|Mystery|Thriller
# 3  tt0133093                The Matrix  1999    8.7  448114      136           Action|Adventure|Sci-Fi
# 4  tt1375666                 Inception  2010    8.9  385149      148  Action|Adventure|Sci-Fi|Thriller

# %%
# Setting up different genres field for each movies
genres=set()
for m in data.genres:
    genres.update(g for g in str(m).split('|'))
genres=sorted(genres)  

# Creating different columns for each genres
for genre in genres:
    data[genre] = [genre in g.split('|') for g in data.genres]

# %%
data.head()
# Out:
#       imdbID                     title  year  score   votes runtime                            genres Action  Adult Adventure Animation Biography Comedy  Crime  Drama Family Fantasy Film-Noir History Horror  Music Musical Mystery   News Reality-TV Romance Sci-Fi  Sport Thriller    War Western
# 0  tt0111161  The Shawshank Redemption  1994    9.2  619479    142                        Crime|Drama  False  False     False     False     False  False   True   True  False   False     False   False  False  False   False   False  False      False   False  False  False    False  False   False
# 1  tt0110912              Pulp Fiction  1994    9.0  490065    154                     Crime|Thriller  False  False     False     False     False  False   True  False  False   False     False   False  False  False   False   False  False      False   False  False  False     True  False   False
# ...

# %%
# Some Questions:
'''
Movie with highest rating? Similarly highest in other fields?
group by movies as per genres
highest vote but low rating
low rating but more votes
movie by decades
best movie in each decade
'''

# %% [markdown]
# #3. Explore global properties

# %%
data[['score', 'year', 'votes', 'runtime']].describe()
# Out:
#              score         year          votes      runtime
# count  9999.000000  9999.000000    9999.000000  9999.000000
# mean      6.385989  1993.471447   16605.462946   103.580358
# std       1.189965    14.830049   34564.883945    26.629310
# min       1.500000  1950.000000    1356.000000     0.000000
# 25%       5.700000  1986.000000    2334.500000    93.000000
# 50%       6.600000  1998.000000    4981.000000   102.000000
# 75%       7.200000  2005.000000   15278.500000   115.000000
# max       9.200000  2011.000000  619479.000000   450.000000

# %%
print len(data[data.runtime == 0])

# Flag those bad data as NAN
data[data.runtime == 0] = np.nan
# Out:
# 282

# %%
data.runtime.describe()
# Out:
# count    9717.000000
# mean      106.586395
# std        20.230330
# min        45.000000
# 25%        93.000000
# 50%       103.000000
# 75%       115.000000
# max       450.000000
# Name: runtime, dtype: float64

# %%
plt.hist(data.year, bins=np.arange(1950,2013), color='#cccccc')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
# In the below graph we can see that number of movies increased with the years...

# %%
plt.hist(data.score, bins=np.arange(20), color='#cccccc')
plt.xlabel('IMDB Rating')
plt.ylabel('Number of Movies')

# %%
plt.hist(data.runtime.dropna(), bins=50, color='#cccccc')
plt.xlabel("Runtime distribution")
remove_border()

# %%
plt.scatter(data.year, data.score, lw=0, alpha=.08, color='g')
plt.xlabel("Year")
plt.ylabel("IMDB Rating")
remove_border()

# %%
plt.scatter(data.votes, data.score, lw=0, alpha=.2, color='k')
plt.xlabel("Number of Votes")
plt.ylabel("IMDB Rating")
plt.xscale('log')

# %%
# detecting outliers i.e. movies with more number of votes but low ratings
data[(data.votes > 9e4) & (data.score <5)][['imdbID','title', 'year', 'score', 'votes', 'genres']]
# Out:
#         imdbID           title  year  score  votes                           genres
# 317  tt1259571        New Moon  2009    4.5  90457  Adventure|Drama|Fantasy|Romance
# 334  tt0118688  Batman & Robin  1997    3.5  91875      Action|Crime|Fantasy|Sci-Fi

# %%
# The lowest rated movie
data[data.score == data.score.min()]
# Out:
#          imdbID                         title  year  score  votes  runtime                              genres
# 1982  tt0060666      Manos: The Hands of Fate  1966    1.5  20927       74                              Horror
# 2793  tt0270846  Superbabies: Baby Geniuses 2  2004    1.5  13196       88                       Comedy|Family
# 3746  tt0421051             Daniel the Wizard  2004    1.5   8271       81  Comedy|Crime|Family|Fantasy|Horror
# 5158  tt0364986                  Ben & Arthur  2002    1.5   4675       85                       Drama|Romance
# 5993  tt0060753     Night Train to Mundo Fine  1966    1.5   3542       89          Action|Adventure|Crime|War
# 6257  tt0059464               Monster a-Go Go  1965    1.5   3255       70                       Sci-Fi|Horror

# %%
# Movies with lowest votes
data[data.votes == data.votes.min()]
# Out:
#          imdbID                   title  year  score  votes  runtime                  genres
# 9974  tt0076391                  Mimino  1977    8.2   1356       97                  Comedy
# 9997  tt0060880  The Quiller Memorandum  1966    6.5   1356      104  Drama|Mystery|Thriller
# 9998  tt0152836                    Taal  1999    6.5   1356      179         Musical|Romance
# 9999  tt0279977          The Navigators  2001    6.9   1356       96            Comedy|Drama

# %%
#Movies with highest score
data[data.score == data.score.max()]
# Out:
#        imdbID                     title  year  score   votes  runtime       genres
# 0   tt0111161  The Shawshank Redemption  1994    9.2  619479      142  Crime|Drama
# 26  tt0068646             The Godfather  1972    9.2  474189      175  Crime|Drama
